# %%
#Import
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.action_chains import ActionChains
from webdriver_manager.chrome import ChromeDriverManager
from datetime import datetime
import time
import logging

# %%
#Import webdriver
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# %%
#Define specialty and city resource files
dfSpecialties= pd.read_csv(r'.\specialties-01.csv')
dfCities= pd.read_csv(r'.\cities-01.csv')

# %%
#Define count constant
logger = logging.getLogger()
count = 10000
countClicScrollBy = 10
shortTimeSleep = 3
longTimeSleep = 60

# %%
try:
    for i in range(count):
        print (i, ' cantidad de ciclos')
        for row, specialty in dfSpecialties.iterrows():
            nameSpecialty = specialty['nombre'].lower()
            for row, city in dfCities.iterrows():
                nameCity = city['nombre'].lower()
                
                # Enter the google page
                driver.get('https://www.google.com/')
                #driver.maximize_window()

                # Enter specialty data
                time.sleep(shortTimeSleep)
                driver.find_element("xpath",'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys('agenda medica ecuador ', nameSpecialty, ' ', nameCity)
                driver.find_element("xpath",'/html/body/div[1]/div[4]').click()

                # Click the Google search button
                driver.find_element("xpath",'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[3]/center/input[1]').click()
                time.sleep(shortTimeSleep)

                # Print Specialty and City
                print(nameSpecialty, '-', nameCity, '|', datetime.today().strftime('%Y-%m-%d %H:%M:%S'))

                ############################################################# 
                #          CONDITIONAL TO SELECT SPECIALTY AND CITY         #
                ############################################################# 

                # cardiología-guayaquil
                if nameSpecialty == 'cardiología' and nameCity == 'guayaquil':
                    driver.find_element("xpath",'//*[@id="rso"]/div[1]/div/div/div[2]/ul/li/div/div/div/div[1]/div/a/h3').click()

                # cardiología-quito
                if nameSpecialty == 'cardiología' and nameCity == 'quito':
                    driver.find_element("xpath",'//*[@id="rso"]/div[1]/div/div/div[2]/ul/li/div/div/div/div[1]/div/a/h3').click()

                # ginecología y obstetricia-guayaquil
                if nameSpecialty == 'ginecología y obstetricia' and nameCity == 'guayaquil':
                    driver.find_element("xpath",'//*[@id="rso"]/div[1]/div/div/div[1]/div/div/div[1]/div/a/h3').click()

                # ginecología y obstetricia-quito
                if nameSpecialty == 'ginecología y obstetricia' and nameCity == 'quito':
                    driver.find_element("xpath",'//*[@id="rso"]/div[1]/div/div/div[2]/ul/li/div/div/div/div[1]/div/a/h3').click()

                # otorrinolaringología-guayaquil
                if nameSpecialty == 'otorrinolaringología' and nameCity == 'guayaquil':
                    driver.find_element("xpath",'//*[@id="rso"]/div[1]/div/div/div[1]/div/div/div[1]/div/a/h3').click()

                # otorrinolaringología-quito
                if nameSpecialty == 'otorrinolaringología' and nameCity == 'quito':
                    driver.find_element("xpath",'//*[@id="rso"]/div[1]/div/div/div[2]/ul/li/div/div/div/div[1]/div/a/h3').click()

                # pediatría-guayaquil
                if nameSpecialty == 'pediatría' and nameCity == 'guayaquil':
                    driver.find_element("xpath",'//*[@id="rso"]/div[1]/div/div/div[2]/ul/li/div/div/div/div[1]/div/a/div/cite').click()

                # pediatría-quito
                if nameSpecialty == 'pediatría' and nameCity == 'quito':
                    driver.find_element("xpath",'//*[@id="rso"]/div[1]/div/div/div[1]/div/div/div[1]/div/a/h3').click()

                time.sleep(shortTimeSleep)
                ############################################################# 
                #                       CONDITIONAL END                     #
                ############################################################# 

                # Enter the parameter of the specialty to search
                driver.find_element("xpath",'//*[@id="__layout"]/div/main/div/div/div/form/div[1]/div[1]/div[1]/div[2]/div/div/input').send_keys(nameSpecialty)
                time.sleep(shortTimeSleep)

                # Select specialty
                driver.find_element("xpath",'//*[@id="listbox"]/li[1]/span').click()

                # Enter the parameter of the city to search
                driver.find_element("xpath",'//*[@id="__layout"]/div/main/div/div/div/form/div[1]/div[1]/div[2]/div[2]/div/div/input').send_keys(nameCity)
                time.sleep(shortTimeSleep)

                # Select city
                driver.find_element("xpath",'//*[@id="listbox"]/li[1]/span').click()
                time.sleep(shortTimeSleep)

                ############################################################# 
                #                    SELECT FIRST RESULTAD                  #
                ############################################################# 

                # cardiología-quito
                if nameSpecialty == 'cardiología' and nameCity == 'quito':
                    driver.find_element("xpath",'//*[@id="__layout"]/div/main/div/section[4]/div/div/div[1]/div/div/div[1]/div/div[4]/a[1]').click()

                # ginecología y obstetricia-quito
                if nameSpecialty == 'ginecología y obstetricia' and nameCity == 'quito':
                    driver.find_element("xpath",'//*[@id="__layout"]/div/main/div/section[4]/div/div/div[1]/div/div/div[1]/div/div[4]/a[1]').click()

                # otorrinolaringología-quito
                if nameSpecialty == 'otorrinolaringología' and nameCity == 'quito':
                    driver.find_element("xpath",'//*[@id="__layout"]/div/main/div/section[4]/div/div/div[1]/div[1]/div/div[1]/div/div[4]/a[1]').click()

                # pediatría-quito
                if nameSpecialty == 'pediatría' and nameCity == 'quito':
                    driver.find_element("xpath",'//*[@id="__layout"]/div/main/div/section[4]/div/div/div[1]/div[1]/div/div[1]/div/div[4]/a[1]').click()

                for c in range(countClicScrollBy):
                    time.sleep(1)
                    driver.execute_script("window.scrollBy(0, 100);")
                time.sleep(longTimeSleep)
except Exception as e:
    # %run -i notification-error_telegram.ipynb
    logger.exception('Exception occurred while code execution en script Agenda Medica Ecuador: ' + str(e))
# Out:
# 0  cantidad de ciclos
# cardiología - guayaquil | 2022-09-07 05:07:58
# cardiología - quito | 2022-09-07 05:09:31
# ginecología y obstetricia - guayaquil | 2022-09-07 05:11:06
# ginecología y obstetricia - quito | 2022-09-07 05:12:43
# otorrinolaringología - guayaquil | 2022-09-07 05:14:18
# otorrinolaringología - quito | 2022-09-07 05:15:53
# pediatría - guayaquil | 2022-09-07 05:17:27
# pediatría - quito | 2022-09-07 05:19:00
# continue
# 1  cantidad de ciclos
# cardiología - guayaquil | 2022-09-07 05:19:21
# cardiología - quito | 2022-09-07 05:21:09
# ginecología y obstetricia - guayaquil | 2022-09-07 05:22:50
# ginecología y obstetricia - quito | 2022-09-07 05:24:25
# otorrinolaringología - guayaquil | 2022-09-07 05:26:01
# otorrinolaringología - quito | 2022-09-07 05:27:36
# pediatría - guayaquil | 2022-09-07 05:29:10
# pediatría - quito | 2022-09-07 05:30:43
# continue
# 2  cantidad de ciclos
# cardiología - guayaquil | 2022-09-07 05:30:56
# cardiología - quito | 2022-09-07 05:32:29
# ginecología y obstetricia - guayaquil | 2022-09-07 05:34:04
# ginecología y obstetricia - quito | 2022-09-07 05:35:40
# otorrinolaringología - guayaquil | 2022-09-07 05:37:14
# otorrinolaringología - quito | 2022-09-07 05:38:50
# pediatría - guayaquil | 2022-09-07 05:40:25
# pediatría - quito | 2022-09-07 05:41:59
# continue
# 3  cantidad de ciclos
# cardiología - guayaquil | 2022-09-07 05:42:11
# cardiología - quito | 2022-09-07 05:43:44
# ginecología y obstetricia - guayaquil | 2022-09-07 05:45:19
# ginecología y obstetricia - quito | 2022-09-07 05:46:54
# otorrinolaringología - guayaquil | 2022-09-07 05:48:28
# otorrinolaringología - quito | 2022-09-07 05:50:03
# pediatría - guayaquil | 2022-09-07 05:51:37
# pediatría - quito | 2022-09-07 05:53:10
# continue
# 4  cantidad de ciclos
# cardiología - guayaquil | 2022-09-07 05:53:23
# cardiología - quito | 2022-09-07 05:54:56
# ginecología y obstetricia - guayaquil | 2022-09-07 05:56:31
# ginecología y obstetricia - quito | 2022-09-07 05:58:07
# otorrinolaringología - guayaquil | 2022-09-07 05:59:41
# otorrinolaringología - quito | 2022-09-07 06:01:16
# pediatría - guayaquil | 2022-09-07 06:02:51
# pediatría - quito | 2022-09-07 06:04:25
# continue
# 5  cantidad de ciclos
# cardiología - guayaquil | 2022-09-07 06:04:37
# cardiología - quito | 2022-09-07 06:06:10
# ginecología y obstetricia - guayaquil | 2022-09-07 06:07:45
# ginecología y obstetricia - quito | 2022-09-07 06:09:20
# otorrinolaringología - guayaquil | 2022-09-07 06:10:55
# otorrinolaringología - quito | 2022-09-07 06:12:32
# pediatría - guayaquil | 2022-09-07 06:14:06
# pediatría - quito | 2022-09-07 06:15:39
# continue
# 6  cantidad de ciclos
# cardiología - guayaquil | 2022-09-07 06:15:51
# cardiología - quito | 2022-09-07 06:17:23
# ginecología y obstetricia - guayaquil | 2022-09-07 06:18:59
# ginecología y obstetricia - quito | 2022-09-07 06:20:35
# otorrinolaringología - guayaquil | 2022-09-07 06:22:09
# otorrinolaringología - quito | 2022-09-07 06:23:44
# pediatría - guayaquil | 2022-09-07 06:25:19
# pediatría - quito | 2022-09-07 06:26:53
# continue
# 7  cantidad de ciclos
# cardiología - guayaquil | 2022-09-07 06:27:06
# cardiología - quito | 2022-09-07 06:28:38
# ginecología y obstetricia - guayaquil | 2022-09-07 06:30:13
# ginecología y obstetricia - quito | 2022-09-07 06:31:48
# otorrinolaringología - guayaquil | 2022-09-07 06:33:23
# otorrinolaringología - quito | 2022-09-07 06:34:57
# pediatría - guayaquil | 2022-09-07 06:36:31
# pediatría - quito | 2022-09-07 06:38:04
# continue
# 8  cantidad de ciclos
# cardiología - guayaquil | 2022-09-07 06:38:17
