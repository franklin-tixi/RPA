# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
# Out:
# [WDM] - Downloading: 100%|██████████| 6.21M/6.21M [00:01<00:00, 5.60MB/s]

# %%
count = 10000

for i in range(count):
    #Ingresar a la pagina de google
    driver.get('https://www.google.com/')

    #Ingresar datos de la especialidad 
    driver.find_element("xpath",'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys('agenda medica ecuador otorrinolaringologia quito')
    driver.find_element("xpath",'/html/body/div[1]/div[4]').click()

    # Dar clic en button de buscar de Google
    driver.find_element("xpath",'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[3]/center/input[1]').click()
    time.sleep(1)

    # Dar clic en la pagina de Agenda Medica Ecuador en los resultados de busqueda
    driver.find_element("xpath",'//*[@id="rso"]/div[1]/div/div/div[2]/ul/li/div/div/div/div[1]/div/a/h3').click()

    # Ingresar el parametro de la especialidad para buscar
    driver.find_element("xpath",'//*[@id="__layout"]/div/main/div/div/div/form/div[1]/div[1]/div[1]/div[2]/div/div/input').send_keys('Otorrinolaringología')
    time.sleep(2)

    # Seleccionar la especialidad de otorrinolaringologia
    driver.find_element("xpath",'//*[@id="listbox"]/li[1]/span').click()

    # Ingresar el parametro de la ciudad para buscar
    driver.find_element("xpath",'//*[@id="__layout"]/div/main/div/div/div/form/div[1]/div[1]/div[2]/div[2]/div/div/input').send_keys('Quito')
    time.sleep(2)

    # Seleccionar la especialidad de otorrinolaringologia
    driver.find_element("xpath",'//*[@id="listbox"]/li[1]/span').click()
    print(i,'Cantidad de veces ejecutas')
    time.sleep(10)
# Out:
# 0 Cantidad de veces ejecutas
# 1 Cantidad de veces ejecutas
# 2 Cantidad de veces ejecutas
# 3 Cantidad de veces ejecutas
# 4 Cantidad de veces ejecutas
# 5 Cantidad de veces ejecutas
# 6 Cantidad de veces ejecutas
# 7 Cantidad de veces ejecutas
# 8 Cantidad de veces ejecutas
# 9 Cantidad de veces ejecutas
# 10 Cantidad de veces ejecutas
# 11 Cantidad de veces ejecutas
# 12 Cantidad de veces ejecutas
# 13 Cantidad de veces ejecutas
# 14 Cantidad de veces ejecutas
# 15 Cantidad de veces ejecutas
# 16 Cantidad de veces ejecutas
# 17 Cantidad de veces ejecutas
# 18 Cantidad de veces ejecutas
# 19 Cantidad de veces ejecutas
# 20 Cantidad de veces ejecutas
# 21 Cantidad de veces ejecutas
# 22 Cantidad de veces ejecutas
# 23 Cantidad de veces ejecutas
# 24 Cantidad de veces ejecutas
# 25 Cantidad de veces ejecutas
# 26 Cantidad de veces ejecutas
# 27 Cantidad de veces ejecutas
# 28 Cantidad de veces ejecutas
# 29 Cantidad de veces ejecutas
# 30 Cantidad de veces ejecutas
# 31 Cantidad de veces ejecutas
# 32 Cantidad de veces ejecutas
# 33 Cantidad de veces ejecutas
# 34 Cantidad de veces ejecutas
# 35 Cantidad de veces ejecutas
# 36 Cantidad de veces ejecutas
# 37 Cantidad de veces ejecutas
# 38 Cantidad de veces ejecutas
# 39 Cantidad de veces ejecutas
# 40 Cantidad de veces ejecutas
# 41 Cantidad de veces ejecutas
# 42 Cantidad de veces ejecutas
# 43 Cantidad de veces ejecutas
# 44 Cantidad de veces ejecutas
# 45 Cantidad de veces ejecutas
# 46 Cantidad de veces ejecutas
# 47 Cantidad de veces ejecutas
# 48 Cantidad de veces ejecutas
# 49 Cantidad de veces ejecutas
# 50 Cantidad de veces ejecutas
# 51 Cantidad de veces ejecutas
# 52 Cantidad de veces ejecutas
# 53 Cantidad de veces ejecutas
# 54 Cantidad de veces ejecutas
# 55 Cantidad de veces ejecutas
# 56 Cantidad de veces ejecutas
# 57 Cantidad de veces ejecutas
# 58 Cantidad de veces ejecutas
# 59 Cantidad de veces ejecutas
# 60 Cantidad de veces ejecutas
# 61 Cantidad de veces ejecutas
# 62 Cantidad de veces ejecutas
# 63 Cantidad de veces ejecutas
# 64 Cantidad de veces ejecutas
# 65 Cantidad de veces ejecutas
# 66 Cantidad de veces ejecutas
# 67 Cantidad de veces ejecutas
# 68 Cantidad de veces ejecutas
# 69 Cantidad de veces ejecutas
# 70 Cantidad de veces ejecutas
# 71 Cantidad de veces ejecutas
# 72 Cantidad de veces ejecutas
# 73 Cantidad de veces ejecutas
# 74 Cantidad de veces ejecutas
# 75 Cantidad de veces ejecutas
# 76 Cantidad de veces ejecutas
# 77 Cantidad de veces ejecutas
# 78 Cantidad de veces ejecutas
# 79 Cantidad de veces ejecutas
# 80 Cantidad de veces ejecutas
# 81 Cantidad de veces ejecutas
# 82 Cantidad de veces ejecutas
# 83 Cantidad de veces ejecutas
# 84 Cantidad de veces ejecutas
# 85 Cantidad de veces ejecutas
# 86 Cantidad de veces ejecutas
# 87 Cantidad de veces ejecutas
# 88 Cantidad de veces ejecutas
# 89 Cantidad de veces ejecutas
# 90 Cantidad de veces ejecutas
# 91 Cantidad de veces ejecutas
# 92 Cantidad de veces ejecutas
# 93 Cantidad de veces ejecutas
# 94 Cantidad de veces ejecutas
# 95 Cantidad de veces ejecutas
# 96 Cantidad de veces ejecutas
# 97 Cantidad de veces ejecutas
# 98 Cantidad de veces ejecutas
# 99 Cantidad de veces ejecutas
# 100 Cantidad de veces ejecutas
# 101 Cantidad de veces ejecutas
# 102 Cantidad de veces ejecutas
# 103 Cantidad de veces ejecutas
# 104 Cantidad de veces ejecutas
# 105 Cantidad de veces ejecutas
# 106 Cantidad de veces ejecutas
# 107 Cantidad de veces ejecutas
# 108 Cantidad de veces ejecutas
# 109 Cantidad de veces ejecutas
# 110 Cantidad de veces ejecutas
# 111 Cantidad de veces ejecutas
# 112 Cantidad de veces ejecutas
# 113 Cantidad de veces ejecutas
# 114 Cantidad de veces ejecutas
# 115 Cantidad de veces ejecutas
# 116 Cantidad de veces ejecutas
# 117 Cantidad de veces ejecutas
# 118 Cantidad de veces ejecutas
# 119 Cantidad de veces ejecutas
# 120 Cantidad de veces ejecutas
# 121 Cantidad de veces ejecutas
# 122 Cantidad de veces ejecutas
# 123 Cantidad de veces ejecutas
# 124 Cantidad de veces ejecutas
# 125 Cantidad de veces ejecutas
# 126 Cantidad de veces ejecutas
# 127 Cantidad de veces ejecutas
# 128 Cantidad de veces ejecutas
# 129 Cantidad de veces ejecutas
# 130 Cantidad de veces ejecutas
# 131 Cantidad de veces ejecutas
# 132 Cantidad de veces ejecutas
# 133 Cantidad de veces ejecutas
# 134 Cantidad de veces ejecutas
# 135 Cantidad de veces ejecutas
# 136 Cantidad de veces ejecutas
# 137 Cantidad de veces ejecutas
# 138 Cantidad de veces ejecutas
# 139 Cantidad de veces ejecutas
# 140 Cantidad de veces ejecutas
# 141 Cantidad de veces ejecutas
# 142 Cantidad de veces ejecutas
# 143 Cantidad de veces ejecutas
# 144 Cantidad de veces ejecutas
# 145 Cantidad de veces ejecutas
# 146 Cantidad de veces ejecutas
# 147 Cantidad de veces ejecutas
# 148 Cantidad de veces ejecutas
# 149 Cantidad de veces ejecutas
# 150 Cantidad de veces ejecutas
# 151 Cantidad de veces ejecutas
# 152 Cantidad de veces ejecutas
# 153 Cantidad de veces ejecutas
# 154 Cantidad de veces ejecutas
# 155 Cantidad de veces ejecutas
# 156 Cantidad de veces ejecutas
# 157 Cantidad de veces ejecutas
# 158 Cantidad de veces ejecutas
# 159 Cantidad de veces ejecutas
# 160 Cantidad de veces ejecutas
# 161 Cantidad de veces ejecutas
# 162 Cantidad de veces ejecutas
# 163 Cantidad de veces ejecutas
# 164 Cantidad de veces ejecutas
# 165 Cantidad de veces ejecutas
# 166 Cantidad de veces ejecutas
# 167 Cantidad de veces ejecutas
# 168 Cantidad de veces ejecutas
# 169 Cantidad de veces ejecutas
# 170 Cantidad de veces ejecutas
# 171 Cantidad de veces ejecutas
# 172 Cantidad de veces ejecutas
# 173 Cantidad de veces ejecutas
# 174 Cantidad de veces ejecutas
# 175 Cantidad de veces ejecutas
# 176 Cantidad de veces ejecutas
# 177 Cantidad de veces ejecutas
# 178 Cantidad de veces ejecutas
# 179 Cantidad de veces ejecutas
# 180 Cantidad de veces ejecutas
# 181 Cantidad de veces ejecutas
# 182 Cantidad de veces ejecutas
# 183 Cantidad de veces ejecutas
# 184 Cantidad de veces ejecutas
# 185 Cantidad de veces ejecutas
# 186 Cantidad de veces ejecutas
# 187 Cantidad de veces ejecutas
# 188 Cantidad de veces ejecutas
# 189 Cantidad de veces ejecutas
# 190 Cantidad de veces ejecutas
# 191 Cantidad de veces ejecutas
# 192 Cantidad de veces ejecutas
# 193 Cantidad de veces ejecutas
# 194 Cantidad de veces ejecutas
# 195 Cantidad de veces ejecutas
# 196 Cantidad de veces ejecutas
# 197 Cantidad de veces ejecutas
# 198 Cantidad de veces ejecutas
# 199 Cantidad de veces ejecutas
# 200 Cantidad de veces ejecutas
# 201 Cantidad de veces ejecutas
# 202 Cantidad de veces ejecutas
# 203 Cantidad de veces ejecutas
# 204 Cantidad de veces ejecutas
# 205 Cantidad de veces ejecutas
# 206 Cantidad de veces ejecutas
# 207 Cantidad de veces ejecutas
# 208 Cantidad de veces ejecutas
# 209 Cantidad de veces ejecutas
# 210 Cantidad de veces ejecutas
# 211 Cantidad de veces ejecutas
# 212 Cantidad de veces ejecutas
# 213 Cantidad de veces ejecutas
# 214 Cantidad de veces ejecutas
# 215 Cantidad de veces ejecutas
# 216 Cantidad de veces ejecutas
# 217 Cantidad de veces ejecutas
# 218 Cantidad de veces ejecutas
# 219 Cantidad de veces ejecutas
# 220 Cantidad de veces ejecutas
# 221 Cantidad de veces ejecutas
# 222 Cantidad de veces ejecutas
# 223 Cantidad de veces ejecutas
# 224 Cantidad de veces ejecutas
# 225 Cantidad de veces ejecutas
# 226 Cantidad de veces ejecutas
# 227 Cantidad de veces ejecutas
# 228 Cantidad de veces ejecutas
# 229 Cantidad de veces ejecutas
# 230 Cantidad de veces ejecutas
# 231 Cantidad de veces ejecutas
# 232 Cantidad de veces ejecutas
# 233 Cantidad de veces ejecutas
# 234 Cantidad de veces ejecutas
# 235 Cantidad de veces ejecutas
# 236 Cantidad de veces ejecutas
# 237 Cantidad de veces ejecutas
# 238 Cantidad de veces ejecutas
# 239 Cantidad de veces ejecutas
# 240 Cantidad de veces ejecutas
# 241 Cantidad de veces ejecutas
# 242 Cantidad de veces ejecutas
# 243 Cantidad de veces ejecutas
# 244 Cantidad de veces ejecutas
# 245 Cantidad de veces ejecutas
# 246 Cantidad de veces ejecutas
# 247 Cantidad de veces ejecutas
# 248 Cantidad de veces ejecutas
# 249 Cantidad de veces ejecutas
# 250 Cantidad de veces ejecutas
# 251 Cantidad de veces ejecutas
# 252 Cantidad de veces ejecutas
# 253 Cantidad de veces ejecutas
# 254 Cantidad de veces ejecutas
# 255 Cantidad de veces ejecutas
# 256 Cantidad de veces ejecutas
# 257 Cantidad de veces ejecutas
# 258 Cantidad de veces ejecutas
# 259 Cantidad de veces ejecutas
# 260 Cantidad de veces ejecutas
# 261 Cantidad de veces ejecutas
# 262 Cantidad de veces ejecutas
# 263 Cantidad de veces ejecutas
# 264 Cantidad de veces ejecutas
# 265 Cantidad de veces ejecutas
# 266 Cantidad de veces ejecutas
# 267 Cantidad de veces ejecutas
# 268 Cantidad de veces ejecutas
# 269 Cantidad de veces ejecutas
# 270 Cantidad de veces ejecutas
# 271 Cantidad de veces ejecutas
# 272 Cantidad de veces ejecutas
# 273 Cantidad de veces ejecutas
# 274 Cantidad de veces ejecutas
# 275 Cantidad de veces ejecutas
# 276 Cantidad de veces ejecutas
# 277 Cantidad de veces ejecutas
# 278 Cantidad de veces ejecutas
# 279 Cantidad de veces ejecutas
# 280 Cantidad de veces ejecutas
# 281 Cantidad de veces ejecutas
# 282 Cantidad de veces ejecutas
# 283 Cantidad de veces ejecutas
# 284 Cantidad de veces ejecutas
# 285 Cantidad de veces ejecutas
# 286 Cantidad de veces ejecutas
# 287 Cantidad de veces ejecutas
# 288 Cantidad de veces ejecutas
# 289 Cantidad de veces ejecutas
# 290 Cantidad de veces ejecutas
# 291 Cantidad de veces ejecutas
# 292 Cantidad de veces ejecutas
# 293 Cantidad de veces ejecutas
# 294 Cantidad de veces ejecutas
# 295 Cantidad de veces ejecutas
# 296 Cantidad de veces ejecutas
# 297 Cantidad de veces ejecutas
# 298 Cantidad de veces ejecutas
# 299 Cantidad de veces ejecutas
# 300 Cantidad de veces ejecutas
# 301 Cantidad de veces ejecutas
# 302 Cantidad de veces ejecutas
# 303 Cantidad de veces ejecutas
# 304 Cantidad de veces ejecutas
# 305 Cantidad de veces ejecutas
# 306 Cantidad de veces ejecutas
# 307 Cantidad de veces ejecutas
# 308 Cantidad de veces ejecutas
# 309 Cantidad de veces ejecutas
# 310 Cantidad de veces ejecutas
# 311 Cantidad de veces ejecutas
# 312 Cantidad de veces ejecutas
# 313 Cantidad de veces ejecutas
# 314 Cantidad de veces ejecutas
# 315 Cantidad de veces ejecutas
# 316 Cantidad de veces ejecutas
# 317 Cantidad de veces ejecutas
# 318 Cantidad de veces ejecutas
# 319 Cantidad de veces ejecutas
# 320 Cantidad de veces ejecutas
# 321 Cantidad de veces ejecutas
# 322 Cantidad de veces ejecutas
# 323 Cantidad de veces ejecutas
# 324 Cantidad de veces ejecutas
# 325 Cantidad de veces ejecutas
# 326 Cantidad de veces ejecutas
# 327 Cantidad de veces ejecutas
# 328 Cantidad de veces ejecutas
# 329 Cantidad de veces ejecutas
# 330 Cantidad de veces ejecutas
# 331 Cantidad de veces ejecutas
# 332 Cantidad de veces ejecutas
# 333 Cantidad de veces ejecutas
# 334 Cantidad de veces ejecutas
# 335 Cantidad de veces ejecutas
# 336 Cantidad de veces ejecutas
# 337 Cantidad de veces ejecutas
# 338 Cantidad de veces ejecutas
# 339 Cantidad de veces ejecutas
# 340 Cantidad de veces ejecutas
# 341 Cantidad de veces ejecutas
# 342 Cantidad de veces ejecutas
# 343 Cantidad de veces ejecutas
# 344 Cantidad de veces ejecutas
# 345 Cantidad de veces ejecutas
# 346 Cantidad de veces ejecutas
# 347 Cantidad de veces ejecutas
# 348 Cantidad de veces ejecutas
# 349 Cantidad de veces ejecutas
# 350 Cantidad de veces ejecutas
# 351 Cantidad de veces ejecutas
# 352 Cantidad de veces ejecutas
# 353 Cantidad de veces ejecutas
# 354 Cantidad de veces ejecutas
# 355 Cantidad de veces ejecutas
# 356 Cantidad de veces ejecutas
# 357 Cantidad de veces ejecutas
# 358 Cantidad de veces ejecutas
# 359 Cantidad de veces ejecutas
# 360 Cantidad de veces ejecutas
# 361 Cantidad de veces ejecutas
# 362 Cantidad de veces ejecutas
# 363 Cantidad de veces ejecutas
# 364 Cantidad de veces ejecutas
# 365 Cantidad de veces ejecutas
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [3], in <cell line: 3>()
#      27 time.sleep(2)
#      29 # Seleccionar la especialidad de otorrinolaringologia
# ---> 30 driver.find_element("xpath",'//*[@id="listbox"]/li[1]/span').click()
#      31 print(i,'Cantidad de veces ejecutas')
#      32 time.sleep(10)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webdriver.py:855, in WebDriver.find_element(self, by, value)
#     852     by = By.CSS_SELECTOR
#     853     value = '[name="%s"]' % value
# --> 855 return self.execute(Command.FIND_ELEMENT, {
#     856     'using': by,
#     857     'value': value})['value']
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webdriver.py:428, in WebDriver.execute(self, driver_command, params)
#     426 response = self.command_executor.execute(driver_command, params)
#     427 if response:
# --> 428     self.error_handler.check_response(response)
#     429     response['value'] = self._unwrap_value(
#     430         response.get('value', None))
#     431     return response
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\errorhandler.py:243, in ErrorHandler.check_response(self, response)
#     241         alert_text = value['alert'].get('text')
#     242     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="listbox"]/li[1]/span"}
#   (Session info: chrome=104.0.5112.102)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00E178B3+2193587]
# 	Ordinal0 [0x00DB0681+1771137]
# 	Ordinal0 [0x00CC41A8+803240]
# 	Ordinal0 [0x00CF24A0+992416]
# 	Ordinal0 [0x00CF273B+993083]
# 	Ordinal0 [0x00D1F7C2+1177538]
# 	Ordinal0 [0x00D0D7F4+1103860]
# 	Ordinal0 [0x00D1DAE2+1170146]
# 	Ordinal0 [0x00D0D5C6+1103302]
# 	Ordinal0 [0x00CE77E0+948192]
# 	Ordinal0 [0x00CE86E6+952038]
# 	GetHandleVerifier [0x010C0CB2+2738370]
# 	GetHandleVerifier [0x010B21B8+2678216]
# 	GetHandleVerifier [0x00EA17AA+512954]
# 	GetHandleVerifier [0x00EA0856+509030]
# 	Ordinal0 [0x00DB743B+1799227]
# 	Ordinal0 [0x00DBBB68+1817448]
# 	Ordinal0 [0x00DBBC55+1817685]
# 	Ordinal0 [0x00DC5230+1856048]
# 	BaseThreadInitThunk [0x76CEFA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77927A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77927A6E+238]
