# %%
#Import
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.action_chains import ActionChains
from webdriver_manager.chrome import ChromeDriverManager
from datetime import datetime
import time
import logging
import sys

# %%
#Import webdriver
chromeOptions = webdriver.ChromeOptions()
chromeOptions.add_argument("--incognito")
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), chrome_options=chromeOptions)
# Out:
# C:\Users\Franklin\AppData\Local\Temp\ipykernel_25084\1568194870.py:4: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), chrome_options=chromeOptions)

# %%
#Define specialty and city resource files
dfSpecialties= pd.read_csv(r'.\specialties-01.csv')
dfCities= pd.read_csv(r'.\cities-01.csv')

# %%
#Define count constant
logger = logging.getLogger()
count = 10000
countClicScrollBy = 10
shortTimeSleep = 3
longTimeSleep = 45

# %%
#Method to record the logs
def log(e):
    # %run -i notification-caution_telegram.ipynb
    logger.exception('Exception occurred while code execution en script Agenda Medica Ecuador: ' + str(e))

#Method search
try:
    for i in range(count):
        print ('')
        print (i, ' periodo')
        for row, specialty in dfSpecialties.iterrows():
            nameSpecialty = specialty['nombre'].lower()
            for row, city in dfCities.iterrows():
                nameCity = city['nombre'].lower()
                
                # Enter the google page
                driver.get('https://www.google.com/')
                time.sleep(shortTimeSleep)
                #driver.maximize_window()
                
                # Enter specialty data
                try:
                    driver.find_element("xpath",'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys('agenda medica ecuador ', nameSpecialty, ' ', nameCity)
                    driver.find_element("xpath",'/html/body/div[1]/div[4]').click()
                except Exception as e:
                    log(e)
                    continue
                    
                # Click the Google search button
                driver.find_element("xpath",'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[3]/center/input[1]').click()
                time.sleep(shortTimeSleep)

                # Print Specialty and City
                print(nameSpecialty, '-', nameCity, '|', datetime.today().strftime('%Y-%m-%d %H:%M:%S'))

                ############################################################# 
                #          CONDITIONAL TO SELECT SPECIALTY AND CITY         #
                ############################################################# 

                # cardiología-guayaquil
                try:
                    if nameSpecialty == 'cardiología' and nameCity == 'guayaquil':
                        driver.find_element("xpath",'//*[@id="rso"]/div[2]/div/div/div[2]/ul/li/div/div/div/div[1]/div/a/h3').click()
                except Exception as e:
                    log(e)
                    continue

                # cardiología-quito
                try:
                    if nameSpecialty == 'cardiología' and nameCity == 'quito':
                        driver.find_element("xpath",'//*[@id="rso"]/div[1]/div/div/div[1]/div/div/div[1]/div/a/h3').click()
                except Exception as e:
                    log(e)
                    continue

                # ginecología y obstetricia-guayaquil
                try:
                    if nameSpecialty == 'ginecología y obstetricia' and nameCity == 'guayaquil':
                        driver.find_element("xpath",'//*[@id="rso"]/div[1]/div/div/div[2]/ul/li/div/div/div/div[1]/div/a/h3').click()
                except Exception as e:
                    log(e)
                    continue

                # ginecología y obstetricia-quito
                try:
                    if nameSpecialty == 'ginecología y obstetricia' and nameCity == 'quito':
                        driver.find_element("xpath",'//*[@id="rso"]/div[1]/div/div/div[1]/div/div/div[1]/div/a/h3').click()
                except Exception as e:
                    log(e)
                    continue

                # otorrinolaringología-guayaquil
                try:
                    if nameSpecialty == 'otorrinolaringología' and nameCity == 'guayaquil':
                        driver.find_element("xpath",'//*[@id="rso"]/div[1]/div/div/div[2]/ul/li/div/div/div/div[1]/div/a/h3').click()
                except Exception as e:
                    log(e)
                    continue

                # otorrinolaringología-quito
                try:
                    if nameSpecialty == 'otorrinolaringología' and nameCity == 'quito':
                        driver.find_element("xpath",'//*[@id="rso"]/div[1]/div/div/div[2]/ul/li/div/div/div/div[1]/div/a/h3').click()
                except Exception as e:
                    log(e)
                    continue
                
                # pediatría-guayaquil
                try:
                    if nameSpecialty == 'pediatría' and nameCity == 'guayaquil':
                        driver.find_element("xpath",'//*[@id="rso"]/div[1]/div/div/div[2]/ul/li/div/div/div/div[1]/div/a/div/cite').click()
                except Exception as e:
                    log(e)
                    continue

                # pediatría-quito
                try:
                    if nameSpecialty == 'pediatría' and nameCity == 'quito':
                        driver.find_element("xpath",'//*[@id="rso"]/div[1]/div/div/div[2]/ul/li/div/div/div/div[1]/div/a/h3').click()
                except Exception as e:
                    log(e)
                    continue

                time.sleep(shortTimeSleep)
                ############################################################# 
                #                       CONDITIONAL END                     #
                ############################################################# 

                # Enter the parameter of the specialty to search
                driver.find_element("xpath",'//*[@id="__layout"]/div/main/div/div/div/form/div[1]/div[1]/div[1]/div[2]/div/div/input').send_keys(nameSpecialty)
                time.sleep(shortTimeSleep)

                # Select specialty
                driver.find_element("xpath",'//*[@id="listbox"]/li[1]/span').click()

                # Enter the parameter of the city to search
                driver.find_element("xpath",'//*[@id="__layout"]/div/main/div/div/div/form/div[1]/div[1]/div[2]/div[2]/div/div/input').send_keys(nameCity)
                time.sleep(shortTimeSleep)

                # Select city
                driver.find_element("xpath",'//*[@id="listbox"]/li[1]/span').click()
                time.sleep(shortTimeSleep)

                ############################################################# 
                #                    SELECT FIRST RESULTAD                  #
                ############################################################# 

                # cardiología-quito
                try:
                    if nameSpecialty == 'cardiología' and nameCity == 'quito':
                        driver.find_element("xpath",'//*[@id="__layout"]/div/main/div/section[4]/div/div/div[1]/div/div/div[1]/div/div[4]/a[1]').click()
                except Exception as e:
                    log(e)
                    continue

                # ginecología y obstetricia-quito
                try:
                    if nameSpecialty == 'ginecología y obstetricia' and nameCity == 'quito':
                        driver.find_element("xpath",'//*[@id="__layout"]/div/main/div/section[4]/div/div/div[1]/div/div/div[1]/div/div[4]/a[1]').click()
                except Exception as e:
                    log(e)
                    continue

                # otorrinolaringología-quito
                try:
                    if nameSpecialty == 'otorrinolaringología' and nameCity == 'quito':
                        driver.find_element("xpath",'//*[@id="__layout"]/div/main/div/section[4]/div/div/div[1]/div[1]/div/div[1]/div/div[4]/a[1]').click()
                except Exception as e:
                    log(e)
                    continue

                # pediatría-quito
                try:
                    if nameSpecialty == 'pediatría' and nameCity == 'quito':
                        driver.find_element("xpath",'//*[@id="__layout"]/div/main/div/section[4]/div/div/div[1]/div[1]/div/div[1]/div/div[4]/a[1]').click()
                except Exception as e:
                    log(e)
                    continue

                for c in range(countClicScrollBy):
                    time.sleep(1)
                    driver.execute_script("window.scrollBy(0, 100);")
                time.sleep(longTimeSleep)
                
except Exception as e:
    # %run -i notification-error_telegram.ipynb
    logger.exception('Exception occurred while code execution en script Agenda Medica Ecuador: ' + str(e))
# Out:
# 0  periodo
# cardiología - guayaquil | 2022-09-12 23:12:32
# cardiología - quito | 2022-09-12 23:12:46
# ginecología y obstetricia - guayaquil | 2022-09-12 23:13:05
# ginecología y obstetricia - quito | 2022-09-12 23:13:19
# otorrinolaringología - guayaquil | 2022-09-12 23:13:35
# otorrinolaringología - quito | 2022-09-12 23:13:49
# pediatría - guayaquil | 2022-09-12 23:14:04
# pediatría - quito | 2022-09-12 23:14:17
#
# 1  periodo
# cardiología - guayaquil | 2022-09-12 23:14:32
# cardiología - quito | 2022-09-12 23:14:45
# ginecología y obstetricia - guayaquil | 2022-09-12 23:15:01
# ginecología y obstetricia - quito | 2022-09-12 23:15:16
# otorrinolaringología - guayaquil | 2022-09-12 23:15:33
# otorrinolaringología - quito | 2022-09-12 23:15:51
# pediatría - guayaquil | 2022-09-12 23:16:10
# pediatría - quito | 2022-09-12 23:16:24
#
# 2  periodo
# cardiología - guayaquil | 2022-09-12 23:16:41
# cardiología - quito | 2022-09-12 23:16:56
# ginecología y obstetricia - guayaquil | 2022-09-12 23:17:12
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# Input In [5], in <cell line: 7>()
#     120 # Select city
# --> 121 driver.find_element("xpath",'//*[@id="listbox"]/li[1]/span').click()
#     122 time.sleep(shortTimeSleep)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webelement.py:88, in WebElement.click(self)
#      87 """Clicks the element."""
# ---> 88 self._execute(Command.CLICK_ELEMENT)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webelement.py:396, in WebElement._execute(self, command, params)
#     395 params['id'] = self._id
# --> 396 return self._parent.execute(command, params)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webdriver.py:428, in WebDriver.execute(self, driver_command, params)
#     427 if response:
# --> 428     self.error_handler.check_response(response)
#     429     response['value'] = self._unwrap_value(
#     430         response.get('value', None))
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\errorhandler.py:243, in ErrorHandler.check_response(self, response)
#     242     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243 raise exception_class(message, screen, stacktrace)
#
# ElementClickInterceptedException: Message: element click intercepted: Element <span class="flex items-left justify-left line-clamp-1">...</span> is not clickable at point (732, 180). Other element would receive the click: <div class="fixed inset-0 z-50 blur flex items-center justify-center bg-white md:bg-opacity-90 blur">...</div>
#   (Session info: chrome=105.0.5195.102)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00EBDF13+2219795]
# 	Ordinal0 [0x00E52841+1779777]
# 	Ordinal0 [0x00D6423D+803389]
# 	Ordinal0 [0x00D999D4+1022420]
# 	Ordinal0 [0x00D978C4+1013956]
# 	Ordinal0 [0x00D954AB+1004715]
# 	Ordinal0 [0x00D94117+999703]
# 	Ordinal0 [0x00D89B76+957302]
# 	Ordinal0 [0x00DAE7FC+1107964]
# 	Ordinal0 [0x00D894B4+955572]
# 	Ordinal0 [0x00DAEA14+1108500]
# 	Ordinal0 [0x00DBF192+1175954]
# 	Ordinal0 [0x00DAE616+1107478]
# 	Ordinal0 [0x00D87F89+950153]
# 	Ordinal0 [0x00D88F56+954198]
# 	GetHandleVerifier [0x011B2CB2+3040210]
# 	GetHandleVerifier [0x011A2BB4+2974420]
# 	GetHandleVerifier [0x00F56A0A+565546]
# 	GetHandleVerifier [0x00F55680+560544]
# 	Ordinal0 [0x00E59A5C+1808988]
# 	Ordinal0 [0x00E5E3A8+1827752]
# 	Ordinal0 [0x00E5E495+1827989]
# 	Ordinal0 [0x00E680A4+1867940]
# 	BaseThreadInitThunk [0x75BFFA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x773C7A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x773C7A6E+238]
#
#
# During handling of the above exception, another exception occurred:
#
# gaierror                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# File C:\ProgramData\Anaconda3\lib\socket.py:954, in getaddrinfo(host, port, family, type, proto, flags)
#     953 addrlist = []
# --> 954 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     955     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1040, in HTTPSConnectionPool._validate_conn(self, conn)
#    1039 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1040     conn.connect()
#    1042 if not conn.is_verified:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py:358, in HTTPSConnection.connect(self)
#     356 def connect(self):
#     357     # Add certificate verification
# --> 358     self.sock = conn = self._new_conn()
#     359     hostname = self.host
#
# File C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x000001F05511D850>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     439 if not chunked:
# --> 440     resp = conn.urlopen(
#     441         method=request.method,
#     442         url=url,
#     443         body=request.body,
#     444         headers=request.headers,
#     445         redirect=False,
#     446         assert_same_host=False,
#     447         preload_content=False,
#     448         decode_content=False,
#     449         retries=self.max_retries,
#     450         timeout=timeout
#     451     )
#     453 # Send the request.
#     454 else:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:785, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     783     e = ProtocolError("Connection aborted.", e)
# --> 785 retries = retries.increment(
#     786     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     787 )
#     788 retries.sleep()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='api.telegram.org', port=443): Max retries exceeded with url: /bot5560270829:AAEKwX2PGBR-AnVb3_nPYKBdnKR7Y2GA_tg/sendMessage (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001F05511D850>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_25084\399609430.py:19, in <cell line: 19>()
#      15     r = requests.post('https://api.telegram.org/bot' + idBot + '/sendMessage',
#      16               data={'chat_id': idGroup, 'text': msg, 'parse_mode': 'HTML'})
#      17     #print(r.text)
# ---> 19 sendMessage(msgErrorWhatsapp + hostName)
#
# File ~\AppData\Local\Temp\ipykernel_25084\399609430.py:15, in sendMessage(msg)
#      14 def sendMessage(msg):
# ---> 15     r = requests.post('https://api.telegram.org/bot' + idBot + '/sendMessage',
#      16               data={'chat_id': idGroup, 'text': msg, 'parse_mode': 'HTML'})
#
# File C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py:117, in post(url, data, json, **kwargs)
#     105 def post(url, data=None, json=None, **kwargs):
#     106     r"""Sends a POST request.
#     107
#     108     :param url: URL for the new :class:`Request` object.
#    (...)
#     114     :rtype: requests.Response
#     115     """
# --> 117     return request('post', url, data=data, json=json, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py:645, in Session.send(self, request, **kwargs)
#     642 start = preferred_clock()
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#     648 elapsed = preferred_clock() - start
#
# File C:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py:519, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     515     if isinstance(e.reason, _SSLError):
#     516         # This branch is for urllib3 v1.22 and later.
#     517         raise SSLError(e, request=request)
# --> 519     raise ConnectionError(e, request=request)
#     521 except ClosedPoolError as e:
#     522     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPSConnectionPool(host='api.telegram.org', port=443): Max retries exceeded with url: /bot5560270829:AAEKwX2PGBR-AnVb3_nPYKBdnKR7Y2GA_tg/sendMessage (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001F05511D850>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# Input In [5], in <cell line: 7>()
#     120 # Select city
# --> 121 driver.find_element("xpath",'//*[@id="listbox"]/li[1]/span').click()
#     122 time.sleep(shortTimeSleep)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webelement.py:88, in WebElement.click(self)
#      87 """Clicks the element."""
# ---> 88 self._execute(Command.CLICK_ELEMENT)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webelement.py:396, in WebElement._execute(self, command, params)
#     395 params['id'] = self._id
# --> 396 return self._parent.execute(command, params)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webdriver.py:428, in WebDriver.execute(self, driver_command, params)
#     427 if response:
# --> 428     self.error_handler.check_response(response)
#     429     response['value'] = self._unwrap_value(
#     430         response.get('value', None))
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\errorhandler.py:243, in ErrorHandler.check_response(self, response)
#     242     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243 raise exception_class(message, screen, stacktrace)
#
# ElementClickInterceptedException: Message: element click intercepted: Element <span class="flex items-left justify-left line-clamp-1">...</span> is not clickable at point (732, 180). Other element would receive the click: <div class="fixed inset-0 z-50 blur flex items-center justify-center bg-white md:bg-opacity-90 blur">...</div>
#   (Session info: chrome=105.0.5195.102)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00EBDF13+2219795]
# 	Ordinal0 [0x00E52841+1779777]
# 	Ordinal0 [0x00D6423D+803389]
# 	Ordinal0 [0x00D999D4+1022420]
# 	Ordinal0 [0x00D978C4+1013956]
# 	Ordinal0 [0x00D954AB+1004715]
# 	Ordinal0 [0x00D94117+999703]
# 	Ordinal0 [0x00D89B76+957302]
# 	Ordinal0 [0x00DAE7FC+1107964]
# 	Ordinal0 [0x00D894B4+955572]
# 	Ordinal0 [0x00DAEA14+1108500]
# 	Ordinal0 [0x00DBF192+1175954]
# 	Ordinal0 [0x00DAE616+1107478]
# 	Ordinal0 [0x00D87F89+950153]
# 	Ordinal0 [0x00D88F56+954198]
# 	GetHandleVerifier [0x011B2CB2+3040210]
# 	GetHandleVerifier [0x011A2BB4+2974420]
# 	GetHandleVerifier [0x00F56A0A+565546]
# 	GetHandleVerifier [0x00F55680+560544]
# 	Ordinal0 [0x00E59A5C+1808988]
# 	Ordinal0 [0x00E5E3A8+1827752]
# 	Ordinal0 [0x00E5E495+1827989]
# 	Ordinal0 [0x00E680A4+1867940]
# 	BaseThreadInitThunk [0x75BFFA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x773C7A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x773C7A6E+238]
#
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Input In [5], in <cell line: 7>()
#     163                 time.sleep(longTimeSleep)
#     165 except Exception as e:
# --> 166     get_ipython().run_line_magic('run', '-i notification-error_telegram.ipynb')
#     167     logger.exception('Exception occurred while code execution en script Agenda Medica Ecuador: ' + str(e))
#
# File C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2294, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2292     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2293 with self.builtin_trap:
# -> 2294     result = fn(*args, **kwargs)
#    2295 return result
#
# File C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magics\execution.py:717, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     715     with preserve_keys(self.shell.user_ns, '__file__'):
#     716         self.shell.user_ns['__file__'] = filename
# --> 717         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     718     return
#     720 # Control the response to exit() calls made by the script being run
#
# File C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2800, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2798 result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2799 if raise_exceptions:
# -> 2800     result.raise_error()
#    2801 elif not result.success:
#    2802     break
#
# File C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:240, in ExecutionResult.raise_error(self)
#     238     raise self.error_before_exec
#     239 if self.error_in_exec is not None:
# --> 240     raise self.error_in_exec
#
#     [... skipping hidden 1 frame]
#
# File ~\AppData\Local\Temp\ipykernel_25084\399609430.py:19, in <cell line: 19>()
#      15     r = requests.post('https://api.telegram.org/bot' + idBot + '/sendMessage',
#      16               data={'chat_id': idGroup, 'text': msg, 'parse_mode': 'HTML'})
#      17     #print(r.text)
# ---> 19 sendMessage(msgErrorWhatsapp + hostName)
#
# File ~\AppData\Local\Temp\ipykernel_25084\399609430.py:15, in sendMessage(msg)
#      14 def sendMessage(msg):
# ---> 15     r = requests.post('https://api.telegram.org/bot' + idBot + '/sendMessage',
#      16               data={'chat_id': idGroup, 'text': msg, 'parse_mode': 'HTML'})
#
# File C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py:117, in post(url, data, json, **kwargs)
#     105 def post(url, data=None, json=None, **kwargs):
#     106     r"""Sends a POST request.
#     107
#     108     :param url: URL for the new :class:`Request` object.
#    (...)
#     114     :rtype: requests.Response
#     115     """
# --> 117     return request('post', url, data=data, json=json, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py:645, in Session.send(self, request, **kwargs)
#     642 start = preferred_clock()
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#     648 elapsed = preferred_clock() - start
#
# File C:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py:519, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     515     if isinstance(e.reason, _SSLError):
#     516         # This branch is for urllib3 v1.22 and later.
#     517         raise SSLError(e, request=request)
# --> 519     raise ConnectionError(e, request=request)
#     521 except ClosedPoolError as e:
#     522     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPSConnectionPool(host='api.telegram.org', port=443): Max retries exceeded with url: /bot5560270829:AAEKwX2PGBR-AnVb3_nPYKBdnKR7Y2GA_tg/sendMessage (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001F05511D850>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
