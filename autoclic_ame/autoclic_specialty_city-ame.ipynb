# %%
# Import
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.action_chains import ActionChains
from webdriver_manager.chrome import ChromeDriverManager
from datetime import datetime
import time

# %%
# Import webdriver
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# %%
# Define specialty and city resource files
dfSpecialties= pd.read_csv(r'.\specialties-01.csv')
dfCities= pd.read_csv(r'.\cities-01.csv')

# %%
# Define count constant
count = 10000
countClicScrollBy = 10
shortTimeSleep = 3
longTimeSleep = 30

# %%
for i in range(count):
    print (i, ' count')
    for row, specialty in dfSpecialties.iterrows():
        nameSpecialty = specialty['nombre'].lower()
        for row, city in dfCities.iterrows():
            nameCity = city['nombre'].lower()
            
            # Enter the google page
            driver.get('https://www.google.com/')
            #driver.maximize_window()

            # Enter specialty data
            driver.find_element("xpath",'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys('agenda medica ecuador ', nameSpecialty, ' ', nameCity)
            driver.find_element("xpath",'/html/body/div[1]/div[4]').click()

            # Click the Google search button
            driver.find_element("xpath",'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[3]/center/input[1]').click()
            time.sleep(shortTimeSleep)

            # Print Specialty and City
            print(nameSpecialty, '-', nameCity, '|', datetime.today().strftime('%Y-%m-%d %H:%M:%S'))
            
            ############################################################# 
            #          CONDITIONAL TO SELECT SPECIALTY AND CITY         #
            ############################################################# 
            
            # cardiología-guayaquil
            if nameSpecialty == 'cardiología' and nameCity == 'guayaquil':
                driver.find_element("xpath",'//*[@id="rso"]/div[1]/div/div/div[2]/ul/li/div/div/div/div[1]/div/a/h3').click()

            # cardiología-quito
            if nameSpecialty == 'cardiología' and nameCity == 'quito':
                driver.find_element("xpath",'//*[@id="rso"]/div[1]/div/div/div[2]/ul/li/div/div/div/div[1]/div/a/h3').click()
            
            # ginecología y obstetricia-guayaquil
            if nameSpecialty == 'ginecología y obstetricia' and nameCity == 'guayaquil':
                driver.find_element("xpath",'//*[@id="rso"]/div[1]/div/div/div[1]/div/div/div[1]/div/a/h3').click()
            
            # ginecología y obstetricia-quito
            if nameSpecialty == 'ginecología y obstetricia' and nameCity == 'quito':
                driver.find_element("xpath",'//*[@id="rso"]/div[1]/div/div/div[2]/ul/li/div/div/div/div[1]/div/a/h3').click()
            
            # otorrinolaringología-guayaquil
            if nameSpecialty == 'otorrinolaringología' and nameCity == 'guayaquil':
                driver.find_element("xpath",'//*[@id="rso"]/div[1]/div/div/div[1]/div/div/div[1]/div/a/h3').click()
            
            # otorrinolaringología-quito
            if nameSpecialty == 'otorrinolaringología' and nameCity == 'quito':
                driver.find_element("xpath",'//*[@id="rso"]/div[1]/div/div/div[2]/ul/li/div/div/div/div[1]/div/a/h3').click()
                
            # pediatría-guayaquil
            if nameSpecialty == 'pediatría' and nameCity == 'guayaquil':
                driver.find_element("xpath",'//*[@id="rso"]/div[1]/div/div/div[2]/ul/li/div/div/div/div[1]/div/a/div/cite').click()
                
            # pediatría-quito
            if nameSpecialty == 'pediatría' and nameCity == 'quito':
                try:
                    driver.find_element("xpath",'//*[@id="rso"]/div[1]/div/div/div[1]/div/div/div[1]/div/a/h3').click()
                except:
                    print('error')
            
                finally:
                    print('continue')
                    continue
                
            time.sleep(shortTimeSleep)
            ############################################################# 
            #                       CONDITIONAL END                     #
            ############################################################# 
            
            # Enter the parameter of the specialty to search
            driver.find_element("xpath",'//*[@id="__layout"]/div/main/div/div/div/form/div[1]/div[1]/div[1]/div[2]/div/div/input').send_keys(nameSpecialty)
            time.sleep(shortTimeSleep)

            # Select specialty
            driver.find_element("xpath",'//*[@id="listbox"]/li[1]/span').click()

            # Enter the parameter of the city to search
            driver.find_element("xpath",'//*[@id="__layout"]/div/main/div/div/div/form/div[1]/div[1]/div[2]/div[2]/div/div/input').send_keys(nameCity)
            time.sleep(shortTimeSleep)

            # Select city
            driver.find_element("xpath",'//*[@id="listbox"]/li[1]/span').click()
            time.sleep(shortTimeSleep)
            
            ############################################################# 
            #                    SELECT FIRST RESULTAD                  #
            ############################################################# 
            
            # cardiología-quito
            if nameSpecialty == 'cardiología' and nameCity == 'quito':
                driver.find_element("xpath",'//*[@id="__layout"]/div/main/div/section[4]/div/div/div[1]/div/div/div[1]/div/div[4]/a[1]').click()
            
            # ginecología y obstetricia-quito
            if nameSpecialty == 'ginecología y obstetricia' and nameCity == 'quito':
                driver.find_element("xpath",'//*[@id="__layout"]/div/main/div/section[4]/div/div/div[1]/div/div/div[1]/div/div[4]/a[1]').click()
                
            # otorrinolaringología-quito
            if nameSpecialty == 'otorrinolaringología' and nameCity == 'quito':
                driver.find_element("xpath",'//*[@id="__layout"]/div/main/div/section[4]/div/div/div[1]/div[1]/div/div[1]/div/div[4]/a[1]').click()
            
            # pediatría-quito
            if nameSpecialty == 'pediatría' and nameCity == 'quito':
                driver.find_element("xpath",'//*[@id="__layout"]/div/main/div/section[4]/div/div/div[1]/div[1]/div/div[1]/div/div[4]/a[1]').click()
            
            for c in range(countClicScrollBy):
                time.sleep(1)
                driver.execute_script("window.scrollBy(0, 100);")
            time.sleep(longTimeSleep)
# Out:
# 0  count
# cardiología - guayaquil | 2022-09-05 09:49:33
# cardiología - quito | 2022-09-05 09:50:34
# ginecología y obstetricia - guayaquil | 2022-09-05 09:51:36
# ginecología y obstetricia - quito | 2022-09-05 09:52:38
# otorrinolaringología - guayaquil | 2022-09-05 09:53:39
# otorrinolaringología - quito | 2022-09-05 09:54:40
# pediatría - guayaquil | 2022-09-05 09:55:41
# pediatría - quito | 2022-09-05 09:56:40
# continue
# 1  count
# cardiología - guayaquil | 2022-09-05 09:56:51
# cardiología - quito | 2022-09-05 09:57:50
# ginecología y obstetricia - guayaquil | 2022-09-05 09:58:52
# ginecología y obstetricia - quito | 2022-09-05 09:59:54
# otorrinolaringología - guayaquil | 2022-09-05 10:00:53
# otorrinolaringología - quito | 2022-09-05 10:01:55
# pediatría - guayaquil | 2022-09-05 10:02:56
# pediatría - quito | 2022-09-05 10:03:55
# continue
# 2  count
# cardiología - guayaquil | 2022-09-05 10:04:06
# cardiología - quito | 2022-09-05 10:05:05
# ginecología y obstetricia - guayaquil | 2022-09-05 10:06:07
# ginecología y obstetricia - quito | 2022-09-05 10:07:08
# otorrinolaringología - guayaquil | 2022-09-05 10:08:08
# otorrinolaringología - quito | 2022-09-05 10:09:09
# pediatría - guayaquil | 2022-09-05 10:10:10
# pediatría - quito | 2022-09-05 10:11:09
# continue
# 3  count
# cardiología - guayaquil | 2022-09-05 10:11:20
# cardiología - quito | 2022-09-05 10:12:19
# ginecología y obstetricia - guayaquil | 2022-09-05 10:13:20
# ginecología y obstetricia - quito | 2022-09-05 10:14:21
# otorrinolaringología - guayaquil | 2022-09-05 10:15:21
# otorrinolaringología - quito | 2022-09-05 10:16:23
# pediatría - guayaquil | 2022-09-05 10:17:24
# pediatría - quito | 2022-09-05 10:18:23
# continue
# 4  count
# cardiología - guayaquil | 2022-09-05 10:18:32
# cardiología - quito | 2022-09-05 10:19:31
# ginecología y obstetricia - guayaquil | 2022-09-05 10:20:33
# ginecología y obstetricia - quito | 2022-09-05 10:21:35
# otorrinolaringología - guayaquil | 2022-09-05 10:22:34
# otorrinolaringología - quito | 2022-09-05 10:23:35
# pediatría - guayaquil | 2022-09-05 10:24:36
# pediatría - quito | 2022-09-05 10:25:36
# continue
# 5  count
# cardiología - guayaquil | 2022-09-05 10:25:50
# cardiología - quito | 2022-09-05 10:26:49
# ginecología y obstetricia - guayaquil | 2022-09-05 10:27:51
# ginecología y obstetricia - quito | 2022-09-05 10:28:52
# otorrinolaringología - guayaquil | 2022-09-05 10:29:52
# otorrinolaringología - quito | 2022-09-05 10:30:54
# pediatría - guayaquil | 2022-09-05 10:31:55
# pediatría - quito | 2022-09-05 10:32:55
# continue
# 6  count
# cardiología - guayaquil | 2022-09-05 10:33:04
# cardiología - quito | 2022-09-05 10:34:03
# ginecología y obstetricia - guayaquil | 2022-09-05 10:35:05
# ginecología y obstetricia - quito | 2022-09-05 10:36:06
# otorrinolaringología - guayaquil | 2022-09-05 10:37:08
# otorrinolaringología - quito | 2022-09-05 10:38:15
# pediatría - guayaquil | 2022-09-05 10:39:16
# pediatría - quito | 2022-09-05 10:40:15
# continue
# 7  count
# cardiología - guayaquil | 2022-09-05 10:40:27
# cardiología - quito | 2022-09-05 10:41:26
# ginecología y obstetricia - guayaquil | 2022-09-05 10:42:27
# ginecología y obstetricia - quito | 2022-09-05 10:43:29
# otorrinolaringología - guayaquil | 2022-09-05 10:44:31
# otorrinolaringología - quito | 2022-09-05 10:45:33
# pediatría - guayaquil | 2022-09-05 10:46:35
# pediatría - quito | 2022-09-05 10:47:35
# continue
# 8  count
# cardiología - guayaquil | 2022-09-05 10:47:46
# cardiología - quito | 2022-09-05 10:48:45
# ginecología y obstetricia - guayaquil | 2022-09-05 10:49:47
# ginecología y obstetricia - quito | 2022-09-05 10:50:48
# otorrinolaringología - guayaquil | 2022-09-05 10:51:51
# otorrinolaringología - quito | 2022-09-05 10:52:53
# pediatría - guayaquil | 2022-09-05 10:53:53
# pediatría - quito | 2022-09-05 10:54:53
# continue
# 9  count
# cardiología - guayaquil | 2022-09-05 10:55:04
# cardiología - quito | 2022-09-05 10:56:04
# ginecología y obstetricia - guayaquil | 2022-09-05 10:57:06
# ginecología y obstetricia - quito | 2022-09-05 10:58:08
# otorrinolaringología - guayaquil | 2022-09-05 10:59:09
# otorrinolaringología - quito | 2022-09-05 11:00:10
# pediatría - guayaquil | 2022-09-05 11:01:12
# pediatría - quito | 2022-09-05 11:02:11
# continue
# 10  count
# cardiología - guayaquil | 2022-09-05 11:02:25
# cardiología - quito | 2022-09-05 11:03:24
# ginecología y obstetricia - guayaquil | 2022-09-05 11:04:25
# ginecología y obstetricia - quito | 2022-09-05 11:05:27
# otorrinolaringología - guayaquil | 2022-09-05 11:06:31
