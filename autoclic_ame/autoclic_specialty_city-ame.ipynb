# %%
#Import
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.action_chains import ActionChains
from webdriver_manager.chrome import ChromeDriverManager
from datetime import datetime
import time
import logging

# %%
#Import webdriver
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# %%
#Define specialty and city resource files
dfSpecialties= pd.read_csv(r'.\specialties-01.csv')
dfCities= pd.read_csv(r'.\cities-01.csv')

# %%
#Define count constant
logger = logging.getLogger()
count = 10000
countClicScrollBy = 10
shortTimeSleep = 3
longTimeSleep = 60

# %%
try:
    for i in range(count):
        print (i, ' cantidad de ciclos')
        for row, specialty in dfSpecialties.iterrows():
            nameSpecialty = specialty['nombre'].lower()
            for row, city in dfCities.iterrows():
                nameCity = city['nombre'].lower()
                
                # Enter the google page
                driver.get('https://www.google.com/')
                #driver.maximize_window()

                # Enter specialty data
                time.sleep(shortTimeSleep)
                driver.find_element("xpath",'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys('agenda medica ecuador ', nameSpecialty, ' ', nameCity)
                driver.find_element("xpath",'/html/body/div[1]/div[4]').click()

                # Click the Google search button
                driver.find_element("xpath",'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[3]/center/input[1]').click()
                time.sleep(shortTimeSleep)

                # Print Specialty and City
                print(nameSpecialty, '-', nameCity, '|', datetime.today().strftime('%Y-%m-%d %H:%M:%S'))

                ############################################################# 
                #          CONDITIONAL TO SELECT SPECIALTY AND CITY         #
                ############################################################# 

                # cardiología-guayaquil
                if nameSpecialty == 'cardiología' and nameCity == 'guayaquil':
                    driver.find_element("xpath",'//*[@id="rso"]/div[1]/div/div/div[2]/ul/li/div/div/div/div[1]/div/a/h3').click()

                # cardiología-quito
                if nameSpecialty == 'cardiología' and nameCity == 'quito':
                    driver.find_element("xpath",'//*[@id="rso"]/div[1]/div/div/div[2]/ul/li/div/div/div/div[1]/div/a/h3').click()

                # ginecología y obstetricia-guayaquil
                if nameSpecialty == 'ginecología y obstetricia' and nameCity == 'guayaquil':
                    driver.find_element("xpath",'//*[@id="rso"]/div[1]/div/div/div[1]/div/div/div[1]/div/a/h3').click()

                # ginecología y obstetricia-quito
                if nameSpecialty == 'ginecología y obstetricia' and nameCity == 'quito':
                    driver.find_element("xpath",'//*[@id="rso"]/div[1]/div/div/div[2]/ul/li/div/div/div/div[1]/div/a/h3').click()

                # otorrinolaringología-guayaquil
                if nameSpecialty == 'otorrinolaringología' and nameCity == 'guayaquil':
                    driver.find_element("xpath",'//*[@id="rso"]/div[1]/div/div/div[1]/div/div/div[1]/div/a/h3').click()

                # otorrinolaringología-quito
                if nameSpecialty == 'otorrinolaringología' and nameCity == 'quito':
                    driver.find_element("xpath",'//*[@id="rso"]/div[1]/div/div/div[2]/ul/li/div/div/div/div[1]/div/a/h3').click()

                # pediatría-guayaquil
                if nameSpecialty == 'pediatría' and nameCity == 'guayaquil':
                    driver.find_element("xpath",'//*[@id="rso"]/div[1]/div/div/div[2]/ul/li/div/div/div/div[1]/div/a/div/cite').click()

                # pediatría-quito
                if nameSpecialty == 'pediatría' and nameCity == 'quito':
                    driver.find_element("xpath",'//*[@id="rso"]/div[1]/div/div/div[1]/div/div/div[1]/div/a/h3').click()

                time.sleep(shortTimeSleep)
                ############################################################# 
                #                       CONDITIONAL END                     #
                ############################################################# 

                # Enter the parameter of the specialty to search
                driver.find_element("xpath",'//*[@id="__layout"]/div/main/div/div/div/form/div[1]/div[1]/div[1]/div[2]/div/div/input').send_keys(nameSpecialty)
                time.sleep(shortTimeSleep)

                # Select specialty
                driver.find_element("xpath",'//*[@id="listbox"]/li[1]/span').click()

                # Enter the parameter of the city to search
                driver.find_element("xpath",'//*[@id="__layout"]/div/main/div/div/div/form/div[1]/div[1]/div[2]/div[2]/div/div/input').send_keys(nameCity)
                time.sleep(shortTimeSleep)

                # Select city
                driver.find_element("xpath",'//*[@id="listbox"]/li[1]/span').click()
                time.sleep(shortTimeSleep)

                ############################################################# 
                #                    SELECT FIRST RESULTAD                  #
                ############################################################# 

                # cardiología-quito
                if nameSpecialty == 'cardiología' and nameCity == 'quito':
                    driver.find_element("xpath",'//*[@id="__layout"]/div/main/div/section[4]/div/div/div[1]/div/div/div[1]/div/div[4]/a[1]').click()

                # ginecología y obstetricia-quito
                if nameSpecialty == 'ginecología y obstetricia' and nameCity == 'quito':
                    driver.find_element("xpath",'//*[@id="__layout"]/div/main/div/section[4]/div/div/div[1]/div/div/div[1]/div/div[4]/a[1]').click()

                # otorrinolaringología-quito
                if nameSpecialty == 'otorrinolaringología' and nameCity == 'quito':
                    driver.find_element("xpath",'//*[@id="__layout"]/div/main/div/section[4]/div/div/div[1]/div[1]/div/div[1]/div/div[4]/a[1]').click()

                # pediatría-quito
                if nameSpecialty == 'pediatría' and nameCity == 'quito':
                    driver.find_element("xpath",'//*[@id="__layout"]/div/main/div/section[4]/div/div/div[1]/div[1]/div/div[1]/div/div[4]/a[1]').click()

                for c in range(countClicScrollBy):
                    time.sleep(1)
                    driver.execute_script("window.scrollBy(0, 100);")
                time.sleep(longTimeSleep)
except Exception as e:
    # %run -i notification-error_telegram.ipynb
    logger.exception('Exception occurred while code execution en script Agenda Medica Ecuador: ' + str(e))
# Out:
# 0  cantidad de ciclos
# cardiología - guayaquil | 2022-09-07 06:39:11
# cardiología - quito | 2022-09-07 06:40:42
# ginecología y obstetricia - guayaquil | 2022-09-07 06:42:18
# ginecología y obstetricia - quito | 2022-09-07 06:43:53
# otorrinolaringología - guayaquil | 2022-09-07 06:45:29
# otorrinolaringología - quito | 2022-09-07 06:47:05
# pediatría - guayaquil | 2022-09-07 06:48:38
# pediatría - quito | 2022-09-07 06:50:12
# 1  cantidad de ciclos
# cardiología - guayaquil | 2022-09-07 06:51:48
# cardiología - quito | 2022-09-07 06:53:21
# ginecología y obstetricia - guayaquil | 2022-09-07 06:54:55
# ginecología y obstetricia - quito | 2022-09-07 06:56:31
# otorrinolaringología - guayaquil | 2022-09-07 06:58:07
# otorrinolaringología - quito | 2022-09-07 06:59:43
# pediatría - guayaquil | 2022-09-07 07:01:18
# pediatría - quito | 2022-09-07 07:02:51
# 2  cantidad de ciclos
# cardiología - guayaquil | 2022-09-07 07:04:28
# cardiología - quito | 2022-09-07 07:06:01
# ginecología y obstetricia - guayaquil | 2022-09-07 07:07:36
# ginecología y obstetricia - quito | 2022-09-07 07:09:12
# otorrinolaringología - guayaquil | 2022-09-07 07:10:47
# otorrinolaringología - quito | 2022-09-07 07:12:23
# pediatría - guayaquil | 2022-09-07 07:13:57
# pediatría - quito | 2022-09-07 07:15:30
# 3  cantidad de ciclos
# cardiología - guayaquil | 2022-09-07 07:17:06
# cardiología - quito | 2022-09-07 07:18:40
# ginecología y obstetricia - guayaquil | 2022-09-07 07:20:14
# ginecología y obstetricia - quito | 2022-09-07 07:21:50
# otorrinolaringología - guayaquil | 2022-09-07 07:23:25
# otorrinolaringología - quito | 2022-09-07 07:25:01
# pediatría - guayaquil | 2022-09-07 07:26:35
# pediatría - quito | 2022-09-07 07:28:09
# 4  cantidad de ciclos
# cardiología - guayaquil | 2022-09-07 07:29:47
# cardiología - quito | 2022-09-07 07:31:20
# ginecología y obstetricia - guayaquil | 2022-09-07 07:32:55
# ginecología y obstetricia - quito | 2022-09-07 07:34:31
# otorrinolaringología - guayaquil | 2022-09-07 07:36:04
# otorrinolaringología - quito | 2022-09-07 07:37:40
# pediatría - guayaquil | 2022-09-07 07:39:15
# pediatría - quito | 2022-09-07 07:40:49
# 5  cantidad de ciclos
# cardiología - guayaquil | 2022-09-07 07:42:24
# cardiología - quito | 2022-09-07 07:43:57
# ginecología y obstetricia - guayaquil | 2022-09-07 07:45:33
# ginecología y obstetricia - quito | 2022-09-07 07:47:10
# otorrinolaringología - guayaquil | 2022-09-07 07:48:46
# otorrinolaringología - quito | 2022-09-07 07:50:24
# pediatría - guayaquil | 2022-09-07 07:51:59
# pediatría - quito | 2022-09-07 07:53:33
# 6  cantidad de ciclos
# cardiología - guayaquil | 2022-09-07 07:55:09
# cardiología - quito | 2022-09-07 07:56:40
# ginecología y obstetricia - guayaquil | 2022-09-07 07:58:14
# ginecología y obstetricia - quito | 2022-09-07 07:59:47
# otorrinolaringología - guayaquil | 2022-09-07 08:01:21
# otorrinolaringología - quito | 2022-09-07 08:02:53
# pediatría - guayaquil | 2022-09-07 08:04:27
# pediatría - quito | 2022-09-07 08:05:59
# 7  cantidad de ciclos
# cardiología - guayaquil | 2022-09-07